# %%
import pandas as pd

# URL da planilha do Google Sheets (somente ID)
sheet_id = '10tpwe3_rfH-TZEuXpNT6vCUaqOK1aofZ'

# URL para a planilha no formato CSV
sheet_url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv'

# Carregar os dados da planilha em um DataFrame
df = pd.read_csv(sheet_url)

# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Número de colunas
num_colunas = df.shape[1]
print(f'O número de colunas é: {num_colunas}')
# Out:
# O número de colunas é: 25

# %%
# Número de linhas
num_linhas = df.shape[0]
print(f'O número de linhas é: {num_linhas}')
# Out:
# O número de linhas é: 30000

# %%
# Tipos de características
tipos_de_dados = df.dtypes
print(tipos_de_dados)

# Separando as colunas numéricas e categóricas
colunas_numericas = df.select_dtypes(include=['number']).columns
colunas_categoricas = df.select_dtypes(exclude=['number']).columns

print(f'Características numéricas: {colunas_numericas}')
print(f'Características categóricas: {colunas_categoricas}')
# Out:
# ID                            object
# LIMIT_BAL                      int64
# SEX                            int64
# EDUCATION                      int64
# MARRIAGE                       int64
# AGE                            int64
# PAY_1                         object
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month     int64
# dtype: object
# ...

# %%
# Exibindo estatísticas descritivas das colunas numéricas
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
# Frequência das características categóricas
for col in colunas_categoricas:
    print(f'\nFrequência de {col}:')
    print(df[col].value_counts())
# Out:
# Frequência de ID:
# ID
# 89f8f447-fca8    2
# 7c9b7473-cc2f    2
# 90330d02-82d9    2
# 75938fec-e5ec    2
# 2a793ecf-05c6    2
#                 ..
# bd737997-0eb0    1
# 6d4101a3-72cb    1
# ffba3018-ce71    1
# df11c637-f8c2    1
# ef4d40c5-8697    1
# Name: count, Length: 29687, dtype: int64
#
# Frequência de PAY_1:
# PAY_1
# 0                13402
# -1                5047
# 1                 3261
# Not available     3021
# -2                2476
# 2                 2378
# 3                  292
# 4                   63
# 5                   23
# 8                   17
# 6                   11
# 7                    9
# Name: count, dtype: int64

# %%
# Verificando valores faltantes
dados_faltantes = df.isnull().sum()
print(dados_faltantes)
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
